# %%
import pandas as pd
import sqlite3
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle(r'D:\Projects\Cafe db\filtered_data')

# %%
df.head(2)
# Out:
#              rnm  num_check            datetime        time_eat  smena  \
# 0  6916860058096      92970 2024-01-09 08:06:00  Ранний завтрак    240
# 1  6916860058096      92970 2024-01-09 08:06:00  Ранний завтрак    240
#
#                 good  total_chek  price  pr_bez_nds  avg_price  profit  \
# 0  Яичница с беконом      181.00  45.00       37.50      22.95   14.55
# 1   Сосиски отварные      181.00  65.00       54.17      23.78   30.39
#
#    amount  position_good  summa payment           check_unique  \
# 0    1.00              1 181.00    card  92970 - 6916860058096
# 1    1.00              2 181.00    card  92970 - 6916860058096
#
#             group         on-group seasons      day  hour       date  revenue  \
# 0         Завтрак          Яичница    Зима  Вторник     8 2024-01-09    37.50
# 1  Основное блюдо  Колбаски разные    Зима  Вторник     8 2024-01-09    54.17
#
#      mnth      quart
# 0  Январь  1 Квартал
# 1  Январь  1 Квартал

# %%
df_ = df[df['group'] == 'Контейнер']

# %%
lst_check_container = df_['check_unique'].to_list()

# %%
lst_check_container
# Out:
# ['92972 - 6916860058096',
#  '92978 - 6916860058096',
#  '92979 - 6916860058096',
#  '92980 - 6916860058096',
#  '92983 - 6916860058096',
#  '92984 - 6916860058096',
#  '92987 - 6916860058096',
#  '92990 - 6916860058096',
#  '92994 - 6916860058096',
#  '92995 - 6916860058096',
#  '92996 - 6916860058096',
#  '92996 - 6916860058096',
#  '92997 - 6916860058096',
#  '93001 - 6916860058096',
#  '93006 - 6916860058096',
#  '93007 - 6916860058096',
#  '93008 - 6916860058096',
#  '93009 - 6916860058096',
#  '93009 - 6916860058096',
#  '93010 - 6916860058096',
#  '93019 - 6916860058096',
#  '93020 - 6916860058096',
#  '93021 - 6916860058096',
#  '93023 - 6916860058096',
#  '93030 - 6916860058096',
#  '93031 - 6916860058096',
#  '93035 - 6916860058096',
#  '93040 - 6916860058096',
#  '93041 - 6916860058096',
#  '93054 - 6916860058096',
#  '93055 - 6916860058096',
#  '93057 - 6916860058096',
#  '93057 - 6916860058096',
#  '93060 - 6916860058096',
#  '93061 - 6916860058096',
# ...

# %%
df_container = df[df['check_unique'].isin(lst_check_container)]

# %%
df_container
# Out:
#                   rnm  num_check            datetime        time_eat  smena  \
# 6       6916860058096      92972 2024-01-09 08:07:00  Ранний завтрак    240
# 7       6916860058096      92972 2024-01-09 08:07:00  Ранний завтрак    240
# 17      6916860058096      92978 2024-01-09 08:24:00  Ранний завтрак    240
# 18      6916860058096      92978 2024-01-09 08:24:00  Ранний завтрак    240
# 19      6916860058096      92979 2024-01-09 08:25:00  Ранний завтрак    240
# ...               ...        ...                 ...             ...    ...
# 483038  6916962051742      19202 2024-10-31 18:00:00          Скидки    194
# 483039  6916962051742      19202 2024-10-31 18:00:00          Скидки    194
# 483040  6916962051742      19203 2024-10-31 18:04:00          Скидки    194
# 483041  6916962051742      19203 2024-10-31 18:04:00          Скидки    194
# 483042  6916962051742      19203 2024-10-31 18:04:00          Скидки    194
#
# ...

# %%
#df_container.to_csv('container.csv', index=False)
