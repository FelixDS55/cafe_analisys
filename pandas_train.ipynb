# %%
import pandas as pd
import sqlite3
import numpy as np

# %%
con = sqlite3.connect(r'C:\projects\Cafe\cafe.db')

# %%
df = pd.read_sql("select * from breakfast_at_time", con)

# %%
df.head()
# Out:
#    num_check             datetime  smena                    good  total_chek  \
# 0      92970  2024-01-09 08:06:00    240       Яичница с беконом       181.0
# 1      92970  2024-01-09 08:06:00    240        Сосиски отварные       181.0
# 2      92970  2024-01-09 08:06:00    240  Каша овсяная на молоке       181.0
# 3      92970  2024-01-09 08:06:00    240    Хлеб ржано-пшеничный       181.0
# 4      92971  2024-01-09 08:07:00    240  Каша рисовая на молоке       145.0
#
#    price  amount  position_good  nds_good  sum_bez_nds payment  \
# 0   45.0     1.0              1      7.50        37.50    card
# 1   65.0     1.0              2     10.83        54.17    card
# 2   65.0     1.0              3     10.83        54.17    card
# 3    6.0     1.0              4      1.00         5.00    card
# 4   65.0     1.0              1     10.83        54.17    card
#
#             check_unique            naimenovanie           group  \
# ...

# %%
cnt = df['amount'] > 6
df[cnt]
# Out:
#        num_check             datetime  smena                             good  \
# 5503          31  2024-01-29 10:25:00      1   Контейнер для горячего(черный)
# 6118        1041  2024-01-31 09:23:00      3       Пирог Королевская ватрушка
# 13648      11361  2024-02-28 10:18:00     22                 Блинчик с вишней
# 14874      13083  2024-03-04 10:54:00     25         Пай песочный с брусникой
# 14875      13083  2024-03-04 10:54:00     25                   Кекс Тыквенный
# 15992      14752  2024-03-07 10:16:00     28         Пирог песочный с лимоном
# 15993      14752  2024-03-07 10:16:00     28         Пай песочный с брусникой
# 17035      16284  2024-03-13 09:37:00     31    Блин с ветчиной и сыром 80 гр
# 20346      20868  2024-03-25 10:08:00     39  Пирожок с зеленым луком и яйцом
# 20347      20868  2024-03-25 10:08:00     39                  Пирожок с мясом
# 31112      36335  2024-05-03 08:06:00     66                           Сырник
# ...

# %%
cnt_btw = df['amount'].between(2, 6)
df[cnt]
# Out:
#        num_check             datetime  smena                             good  \
# 5503          31  2024-01-29 10:25:00      1   Контейнер для горячего(черный)
# 6118        1041  2024-01-31 09:23:00      3       Пирог Королевская ватрушка
# 13648      11361  2024-02-28 10:18:00     22                 Блинчик с вишней
# 14874      13083  2024-03-04 10:54:00     25         Пай песочный с брусникой
# 14875      13083  2024-03-04 10:54:00     25                   Кекс Тыквенный
# 15992      14752  2024-03-07 10:16:00     28         Пирог песочный с лимоном
# 15993      14752  2024-03-07 10:16:00     28         Пай песочный с брусникой
# 17035      16284  2024-03-13 09:37:00     31    Блин с ветчиной и сыром 80 гр
# 20346      20868  2024-03-25 10:08:00     39  Пирожок с зеленым луком и яйцом
# 20347      20868  2024-03-25 10:08:00     39                  Пирожок с мясом
# 31112      36335  2024-05-03 08:06:00     66                           Сырник
# ...

# %%
has_blin_in_naimen = df.good.str.lower().str.contains('блин')
df[has_blin_in_naimen]
# Out:
#        num_check             datetime  smena                        good  \
# 13         92977  2024-01-09 08:20:00    240                    Блинчики
# 17         92978  2024-01-09 08:24:00    240  Блинчик с ветчиной и сыром
# 21         92980  2024-01-09 08:26:00    240  Блинчик с ветчиной и сыром
# 22         92980  2024-01-09 08:26:00    240          Блинчик с творогом
# 26         92982  2024-01-09 08:28:00    240  Блинчик с ветчиной и сыром
# ...          ...                  ...    ...                         ...
# 46417      56231  2024-06-28 09:39:00    104             Блинчик с мясом
# 46462      56250  2024-06-28 10:05:00    104             Блинчик с мясом
# 46483      56258  2024-06-28 10:19:00    104             Блинчик с мясом
# 46488      56260  2024-06-28 10:25:00    104             Блинчик с мясом
# 46506      56270  2024-06-28 10:42:00    104             Блинчик с мясом
#
#        total_chek  price  amount  position_good  nds_good  sum_bez_nds  \
# ...

# %% [markdown]
# Группировка данных

# %%
df.head()
# Out:
#    num_check             datetime  smena                    good  total_chek  \
# 0      92970  2024-01-09 08:06:00    240       Яичница с беконом       181.0
# 1      92970  2024-01-09 08:06:00    240        Сосиски отварные       181.0
# 2      92970  2024-01-09 08:06:00    240  Каша овсяная на молоке       181.0
# 3      92970  2024-01-09 08:06:00    240    Хлеб ржано-пшеничный       181.0
# 4      92971  2024-01-09 08:07:00    240  Каша рисовая на молоке       145.0
#
#    price  amount  position_good  nds_good  sum_bez_nds payment  \
# 0   45.0     1.0              1      7.50        37.50    card
# 1   65.0     1.0              2     10.83        54.17    card
# 2   65.0     1.0              3     10.83        54.17    card
# 3    6.0     1.0              4      1.00         5.00    card
# 4   65.0     1.0              1     10.83        54.17    card
#
#             check_unique            naimenovanie           group  \
# ...

# %%
df.dtypes
# Out:
# num_check          int64
# datetime          object
# smena              int64
# good              object
# total_chek       float64
# price            float64
# amount           float64
# position_good      int64
# nds_good         float64
# sum_bez_nds      float64
# payment           object
# check_unique      object
# naimenovanie      object
# group             object
# on-group          object
# mnth              object
# avg_zakup_sum    float64
# profit_good      float64
# dtype: object

# %%
df.groupby(["good"]).agg({"profit_good": sum, 'amount': sum}).sort_values(by='profit_good', ascending=False).reset_index()
# Out:
# C:\Users\Михаил\AppData\Local\Temp\ipykernel_9324\2263211429.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby(["good"]).agg({"profit_good": sum, 'amount': sum}).sort_values(by='profit_good', ascending=False).reset_index()
# C:\Users\Михаил\AppData\Local\Temp\ipykernel_9324\2263211429.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby(["good"]).agg({"profit_good": sum, 'amount': sum}).sort_values(by='profit_good', ascending=False).reset_index()
#                             good  profit_good  amount
# 0              Горячий бутерброд     91848.98  2283.0
# ...

# %% [markdown]
# **Объект Series**
